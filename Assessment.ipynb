# %%
import pandas as pd 
import numpy as np

# %%
pd1 = pd.read_csv('restaurant.csv')
pd2 = pd.read_csv('item.csv')

# %%
pd1.median()
# Out:
# C:\Users\asus\AppData\Local\Temp/ipykernel_16268/1785905006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd1.median()
# id                    5.050000e+01
# rating                3.000000e+00
# delivers              1.000000e+00
# pick_ups              1.000000e+00
# verified              1.000000e+00
# closed                0.000000e+00
# owner_id              3.100000e+01
# abn                   7.030396e+10
# is_gst_registered     1.000000e+00
# website_url                    NaN
# google_maps_id        6.693218e+07
# min_delivery_value    1.000000e+01
# is_boosted            0.000000e+00
# dtype: float64

# %%
pd2['restaurant_id'].coun
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 1216    95
# 1217    96
# 1218    97
# 1219    98
# 1220    99
# Name: restaurant_id, Length: 1221, dtype: int64

# %%
pd1.describe(include= 'all')
# Out:
#                 id         name                               address  \
# count   100.000000          100                                   100
# unique         NaN           99                                    93
# top            NaN  Ayam Goreng  387 Victoria St, Abbotsford VIC 3067
# freq           NaN            2                                     2
# mean     53.200000          NaN                                   NaN
# std      32.928757          NaN                                   NaN
# min       1.000000          NaN                                   NaN
# 25%      25.750000          NaN                                   NaN
# 50%      50.500000          NaN                                   NaN
# 75%      77.250000          NaN                                   NaN
# max     122.000000          NaN                                   NaN
#
#             rating     type    delivers    pick_ups       state   verified  \
# ...

# %%
pd1.sort_values[]
